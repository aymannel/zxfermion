# %%
# %load_ext autoreload
# %autoreload 2

import pyzx as zx
from zxfermion.gates import CX, CZ, X, Z
from zxfermion.gadgets import Gadget, GadgetCircuit
from zxfermion.types import VertexType, LegType, Node, LegX, LegY, LegZ
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
circuit = GadgetCircuit(num_qubits=5, gadgets=[
    Gadget('YZZZX', phase=1/2),
    Gadget('XZZZY', phase=-1/2),
])

circuit.draw()
circuit.surround_cx(control=1, target=2)
circuit.surround_cx(control=2, target=3)
circuit.surround_cx(control=0, target=4)
circuit.surround_cz(control=0, target=3)
# Out:
# <div style="overflow:auto" id="graph-output-JP9hGhkE"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://cdn.skypack.dev/d3@5"); }
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# // styling functions
# function nodeColor(t) {
# ...

# %%
circuit = GadgetCircuit(num_qubits=4, gadgets=[
    Gadget('YXXX', phase=1/4),
    Gadget('XYXX', phase=1/4),
    Gadget('XXYX', phase=-1/4),
    Gadget('YYYX', phase=-1/4),
    Gadget('YYXY', phase=1/4),
    Gadget('XXXY', phase=1/4),
    Gadget('XYYY', phase=-1/4),
    Gadget('YXYY', phase=-1/4),
])

circuit.draw()
circuit.surround_cx(control=0, target=1)
circuit.surround_cx(control=2, target=3)
circuit.surround_cx(control=0, target=2)
#circuit.surround_x(qubit=1)
#circuit.surround_x(qubit=3)
circuit.surround_cx(control=3, target=0, left=9, right=14)
circuit.surround_cx(control=2, target=0, left=7, right=13)
# Out:
# <div style="overflow:auto" id="graph-output-82kt6A5u"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://cdn.skypack.dev/d3@5"); }
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# // styling functions
# function nodeColor(t) {
# ...

# %%
circuit = GadgetCircuit(num_qubits=4, gadgets=[
    Gadget('YXXX', phase=1/4),
    Gadget('XYXX', phase=1/4),
    Gadget('XXYX', phase=-1/4),
    Gadget('YYYX', phase=-1/4),
    Gadget('YYXY', phase=1/4),
    Gadget('XXXY', phase=1/4),
    Gadget('XYYY', phase=-1/4),
    Gadget('YXYY', phase=-1/4),
])

circuit.draw()
circuit.surround_cx(control=3, target=0)
circuit.surround_cx(control=3, target=1)
circuit.surround_cx(control=3, target=2)
#circuit.surround_x(qubit=2)
# Out:
# <div style="overflow:auto" id="graph-output-EjSaqgUM"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://cdn.skypack.dev/d3@5"); }
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# // styling functions
# function nodeColor(t) {
# ...

# %%
circuit = GadgetCircuit(num_qubits=4, gadgets=[
    Gadget('YXXX', phase=1/4),
    Gadget('XYXX', phase=1/4),
    Gadget('XXYX', phase=-1/4),
    Gadget('YYYX', phase=-1/4),
    Gadget('YYXY', phase=1/4),
    Gadget('XXXY', phase=1/4),
    Gadget('XYYY', phase=-1/4),
    Gadget('YXYY', phase=-1/4),
])

circuit.draw()
circuit.surround_cx(control=0, target=1)
circuit.surround_cx(control=0, target=2)
circuit.surround_cx(control=0, target=3)
circuit.surround_cx(control=0, target=3)

#for x, y in zip(circuit.gadgets, circuit.gadgets[1:]):
    #print(x, y)
# Out:
# <div style="overflow:auto" id="graph-output-i4SIWTXk"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://cdn.skypack.dev/d3@5"); }
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# // styling functions
# function nodeColor(t) {
# ...

# %%
circuit = GadgetCircuit(num_qubits=4, gadgets=[
    Gadget('YIII', 1/4), Gadget('YZII', -1/4), CX(2, 0),
    Gadget('YIII', 1/4), Gadget('YZII', -1/4), CX(3, 0),
    Gadget('YIII', 1/4), Gadget('YZII', -1/4), CX(2, 0),
    Gadget('YIII', 1/4), Gadget('YZII', -1/4), CX(3, 0),
])

circuit.draw()
circuit.surround_cx(control=2, target=0, left=3, right=10)
circuit.surround_cx(control=3, target=0, left=6)
# Out:
# <div style="overflow:auto" id="graph-output-50bKg2S3"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://cdn.skypack.dev/d3@5"); }
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# // styling functions
# function nodeColor(t) {
# ...

# %%
circuit = GadgetCircuit(num_qubits=6, gadgets=[
    Gadget('YZZZXI', 1/4),
    Gadget('XZZZYI', 1/4),
    Gadget('IYZZZX', -1/4),
    Gadget('IXZZZY', -1/4),
])

circuit.draw()
circuit.surround_cx(control=0, target=4)
# Out:
# <div style="overflow:auto" id="graph-output-cYcFx6LQ"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://cdn.skypack.dev/d3@5"); }
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# // styling functions
# function nodeColor(t) {
# ...

# %%
gadget = Gadget('YZZX')
gadget.draw()
# Out:
# <div style="overflow:auto" id="graph-output-gBUvRMJp"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://cdn.skypack.dev/d3@5"); }
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# // styling functions
# function nodeColor(t) {
# ...
