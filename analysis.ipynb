# %%
# %load_ext autoreload
# %autoreload 2

from zxfermion.types import Node, GadgetLeg, Gadget, GadgetCircuit
from openfermion import FermionOperator, QubitOperator, jordan_wigner

import pyscf
import pyzx as zx
import numpy as np
import openfermionpyscf
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# ansatze with same operator set

linear_ansatze = [Ansatz(result_id=f'{i}.{j}', geometry='H4_linear')
                  for i in range(1, 9)
                  for j in range(1, 11)]

grouped_ansatze = {}
for ansatz in linear_ansatze:
    ansatz_set = frozenset(ansatz.operator_order)
    if ansatz_set in grouped_ansatze:
        grouped_ansatze[ansatz_set].append(ansatz)
    else:
        grouped_ansatze[ansatz_set] = [ansatz]

grouped_ansatze = list(grouped_ansatze.values())
grouped_ansatze.sort(reverse=True, key=lambda group: len(group))

print(f'Total ansatze number: {len(linear_ansatze)}')
print(f'Unique ansatze number: {len(grouped_ansatze)}')
print(f'Largest group size: {len(grouped_ansatze[0])}', '\n')

for idx, group in enumerate(grouped_ansatze):
    unique_ansatze = len(set([tuple(ansatz.operator_order) for ansatz in group]))
    print(f'Group: {idx+1}    Unique Ansatze: {unique_ansatze}')
    for ansatz in group:
        print(f'Result ID: {ansatz.result_id}    Operator Order: {ansatz.operator_order}')
    print()
# Out:
# Total ansatze number: 80
# Unique ansatze number: 30
# Largest group size: 18
#
# Group: 1    Unique Ansatze: 15
# Result ID: 1.1    Operator Order: [8, 7, 6, 12, 9, 1, 7, 2, 5, 11, 10, 2, 5, 11]
# Result ID: 1.3    Operator Order: [10, 1, 7, 12, 8, 6, 5, 2, 7, 11, 9, 5, 10, 11]
# Result ID: 1.4    Operator Order: [9, 6, 10, 1, 6, 10, 9, 5, 2, 7, 11, 9, 8, 12]
# Result ID: 1.6    Operator Order: [10, 6, 9, 6, 1, 7, 9, 8, 12, 2, 5, 10, 9, 11]
# Result ID: 2.2    Operator Order: [9, 10, 1, 6, 2, 11, 8, 2, 5, 7, 12, 2, 8, 9]
# Result ID: 2.5    Operator Order: [10, 6, 7, 11, 1, 5, 9, 12, 2, 9, 8, 2, 7, 8]
# Result ID: 2.6    Operator Order: [9, 6, 10, 1, 6, 10, 9, 5, 2, 7, 11, 9, 8, 12]
# Result ID: 3.1    Operator Order: [8, 6, 7, 10, 1, 11, 10, 2, 8, 9, 5, 11, 12, 10]
# Result ID: 3.3    Operator Order: [8, 6, 7, 10, 1, 11, 10, 2, 8, 9, 5, 11, 12, 10]
# Result ID: 3.10    Operator Order: [10, 7, 6, 11, 1, 5, 7, 12, 8, 2, 11, 7, 9, 2]
# Result ID: 4.5    Operator Order: [11, 1, 9, 1, 6, 12, 8, 5, 12, 2, 5, 10, 7, 10]
# Result ID: 4.8    Operator Order: [9, 11, 1, 8, 6, 7, 12, 2, 5, 11, 10, 5, 11, 9]
# Result ID: 5.1    Operator Order: [10, 7, 12, 6, 8, 1, 10, 11, 5, 2, 12, 5, 7, 9]
# Result ID: 5.2    Operator Order: [10, 11, 1, 12, 11, 6, 2, 8, 7, 2, 11, 9, 5, 11]
# Result ID: 5.6    Operator Order: [11, 1, 9, 1, 6, 12, 8, 5, 12, 2, 5, 10, 7, 10]
# Result ID: 6.4    Operator Order: [10, 1, 8, 1, 6, 9, 12, 5, 2, 9, 10, 7, 12, 11]
# Result ID: 7.4    Operator Order: [10, 7, 1, 6, 8, 1, 10, 11, 5, 2, 12, 5, 7, 9]
# Result ID: 8.4    Operator Order: [9, 1, 6, 10, 1, 6, 9, 5, 2, 12, 8, 9, 7, 11]
#
# Group: 2    Unique Ansatze: 8
# Result ID: 1.5    Operator Order: [9, 12, 1, 7, 8, 6, 12, 11, 2, 5, 12, 9, 11, 2]
# Result ID: 1.8    Operator Order: [11, 6, 11, 7, 9, 1, 11, 2, 5, 7, 11, 5, 12, 8]
# Result ID: 3.2    Operator Order: [8, 6, 7, 11, 1, 12, 2, 7, 9, 11, 5, 11, 9, 11]
# Result ID: 3.7    Operator Order: [11, 9, 1, 8, 6, 2, 12, 2, 7, 5, 11, 9, 2, 8]
# Result ID: 3.8    Operator Order: [8, 6, 9, 7, 8, 1, 9, 5, 2, 11, 9, 11, 12, 5]
# Result ID: 5.9    Operator Order: [8, 6, 11, 1, 6, 8, 11, 12, 9, 2, 8, 5, 7, 8]
# Result ID: 6.9    Operator Order: [9, 6, 9, 7, 9, 8, 1, 5, 2, 11, 12, 11, 12, 5]
# Result ID: 6.10    Operator Order: [9, 6, 9, 7, 8, 9, 1, 5, 2, 11, 12, 11, 12, 5]
#
# Group: 3    Unique Ansatze: 5
# Result ID: 2.3    Operator Order: [9, 10, 1, 6, 5, 7, 5, 10, 11, 12, 2, 9, 11, 5]
# Result ID: 3.4    Operator Order: [9, 6, 10, 6, 1, 11, 2, 5, 7, 10, 2, 5, 12, 11]
# Result ID: 3.5    Operator Order: [9, 6, 10, 6, 1, 11, 2, 5, 10, 7, 2, 5, 12, 11]
# Result ID: 3.9    Operator Order: [9, 6, 10, 6, 1, 11, 2, 5, 7, 10, 2, 5, 12, 11]
# Result ID: 4.7    Operator Order: [10, 6, 9, 6, 1, 11, 2, 5, 7, 10, 7, 5, 12, 11]
# Result ID: 5.4    Operator Order: [10, 12, 1, 11, 6, 7, 2, 11, 12, 5, 10, 11, 7, 9]
#
# Group: 4    Unique Ansatze: 5
# Result ID: 2.4    Operator Order: [10, 6, 9, 6, 1, 5, 12, 8, 5, 9, 2, 10, 9, 7]
# Result ID: 7.3    Operator Order: [9, 10, 1, 7, 6, 5, 2, 12, 8, 12, 8, 2, 9, 5]
# Result ID: 8.6    Operator Order: [9, 1, 6, 10, 1, 6, 9, 5, 2, 12, 8, 9, 10, 7]
# Result ID: 8.8    Operator Order: [9, 1, 6, 10, 1, 6, 9, 5, 2, 12, 8, 7, 9, 10]
# Result ID: 8.10    Operator Order: [9, 1, 6, 10, 1, 6, 9, 5, 2, 12, 9, 8, 7, 10]
#
# Group: 5    Unique Ansatze: 4
# Result ID: 1.7    Operator Order: [9, 7, 6, 8, 9, 1, 8, 2, 5, 7, 10, 2, 5, 11]
# Result ID: 2.7    Operator Order: [10, 9, 5, 6, 10, 1, 2, 5, 10, 11, 8, 5, 7, 2]
# Result ID: 6.6    Operator Order: [8, 6, 7, 9, 1, 10, 8, 2, 7, 5, 11, 10, 8, 10]
# Result ID: 8.7    Operator Order: [10, 11, 6, 11, 1, 8, 9, 5, 7, 11, 2, 8, 10, 9]
#
# Group: 6    Unique Ansatze: 3
# Result ID: 1.9    Operator Order: [8, 1, 11, 1, 6, 9, 2, 11, 8, 9, 5, 12, 11, 5]
# Result ID: 2.1    Operator Order: [9, 8, 6, 9, 12, 1, 8, 2, 12, 2, 11, 12, 5, 9]
# Result ID: 7.5    Operator Order: [9, 6, 8, 1, 6, 9, 8, 2, 5, 12, 2, 8, 2, 11]
# Result ID: 7.6    Operator Order: [9, 6, 8, 1, 6, 9, 8, 2, 5, 12, 2, 8, 2, 11]
#
# Group: 7    Unique Ansatze: 4
# Result ID: 2.8    Operator Order: [11, 1, 9, 1, 6, 5, 8, 12, 11, 2, 5, 10, 5, 12]
# Result ID: 2.10    Operator Order: [10, 9, 5, 6, 10, 1, 2, 5, 10, 11, 12, 5, 8, 2]
# Result ID: 3.6    Operator Order: [8, 1, 12, 10, 8, 6, 8, 2, 5, 9, 5, 10, 11, 10]
# Result ID: 6.5    Operator Order: [8, 1, 11, 6, 1, 10, 5, 12, 11, 5, 12, 2, 9, 10]
#
# Group: 8    Unique Ansatze: 4
# Result ID: 4.4    Operator Order: [4, 3, 10, 12, 9, 12, 3, 7, 2, 5, 7, 11, 12, 5]
# Result ID: 5.8    Operator Order: [4, 3, 10, 7, 9, 7, 3, 7, 2, 5, 11, 12, 11, 5]
# Result ID: 6.7    Operator Order: [4, 3, 10, 12, 9, 12, 3, 7, 2, 5, 12, 11, 7, 5]
# Result ID: 6.8    Operator Order: [4, 3, 10, 12, 9, 12, 3, 7, 2, 5, 10, 12, 11, 5]
#
# Group: 9    Unique Ansatze: 1
# Result ID: 4.1    Operator Order: [9, 2, 12, 5, 10, 3, 9, 3, 12, 11, 12, 5, 9, 12]
# Result ID: 4.2    Operator Order: [9, 2, 12, 5, 10, 3, 9, 3, 12, 11, 12, 5, 9, 12]
# Result ID: 4.3    Operator Order: [9, 2, 12, 5, 10, 3, 9, 3, 12, 11, 12, 5, 9, 12]
#
# Group: 10    Unique Ansatze: 2
# Result ID: 2.9    Operator Order: [11, 6, 1, 9, 6, 1, 9, 5, 11, 2, 7, 11, 8, 9]
# Result ID: 4.6    Operator Order: [8, 6, 11, 6, 1, 9, 8, 5, 11, 5, 7, 2, 9, 11]
#
# Group: 11    Unique Ansatze: 2
# Result ID: 5.7    Operator Order: [9, 1, 10, 6, 1, 5, 11, 9, 2, 12, 11, 12, 5, 9]
# Result ID: 5.10    Operator Order: [9, 1, 10, 6, 1, 5, 9, 11, 2, 12, 11, 12, 5, 9]
#
# Group: 12    Unique Ansatze: 1
# Result ID: 8.1    Operator Order: [4, 8, 9, 7, 3, 12, 9, 11, 5, 10, 11, 12, 2, 9]
# Result ID: 8.2    Operator Order: [4, 8, 9, 7, 3, 12, 9, 11, 5, 10, 11, 12, 2, 9]
#
# Group: 13    Unique Ansatze: 1
# Result ID: 1.2    Operator Order: [11, 10, 12, 6, 10, 1, 2, 5, 12, 2, 10, 11, 5, 11]
#
# Group: 14    Unique Ansatze: 1
# Result ID: 1.10    Operator Order: [8, 1, 11, 1, 6, 2, 12, 5, 7, 11, 12, 10, 5, 12]
#
# Group: 15    Unique Ansatze: 1
# Result ID: 4.9    Operator Order: [2, 6, 7, 9, 12, 1, 7, 2, 5, 8, 7, 2, 8, 9]
#
# Group: 16    Unique Ansatze: 1
# Result ID: 4.10    Operator Order: [8, 1, 7, 6, 12, 8, 6, 5, 7, 10, 2, 10, 2, 8]
#
# Group: 17    Unique Ansatze: 1
# Result ID: 5.3    Operator Order: [8, 1, 8, 10, 8, 1, 6, 3, 9, 3, 12, 11, 5, 11]
#
# Group: 18    Unique Ansatze: 1
# Result ID: 5.5    Operator Order: [10, 6, 9, 6, 1, 8, 9, 8, 12, 2, 5, 12, 9, 12]
#
# Group: 19    Unique Ansatze: 1
# Result ID: 6.1    Operator Order: [5, 2, 9, 8, 3, 9, 3, 2, 11, 9, 5, 11, 5, 7]
#
# Group: 20    Unique Ansatze: 1
# Result ID: 6.2    Operator Order: [5, 2, 9, 8, 3, 9, 3, 2, 11, 9, 7, 11, 5, 12]
#
# Group: 21    Unique Ansatze: 1
# Result ID: 6.3    Operator Order: [5, 8, 10, 2, 7, 8, 3, 10, 9, 3, 2, 7, 9, 7]
#
# Group: 22    Unique Ansatze: 1
# Result ID: 7.1    Operator Order: [2, 5, 9, 7, 5, 2, 6, 12, 6, 11, 10, 9, 5, 8]
#
# Group: 23    Unique Ansatze: 1
# Result ID: 7.2    Operator Order: [10, 11, 12, 11, 5, 2, 3, 9, 3, 8, 7, 9, 2, 8]
#
# Group: 24    Unique Ansatze: 1
# Result ID: 7.7    Operator Order: [4, 3, 10, 12, 9, 12, 3, 11, 2, 5, 11, 12, 11, 5]
#
# Group: 25    Unique Ansatze: 1
# Result ID: 7.8    Operator Order: [11, 2, 9, 5, 8, 3, 10, 1, 10, 2, 12, 5, 9, 5]
#
# Group: 26    Unique Ansatze: 1
# Result ID: 7.9    Operator Order: [11, 2, 7, 5, 4, 3, 12, 11, 10, 8, 9, 12, 4, 6]
#
# Group: 27    Unique Ansatze: 1
# Result ID: 7.10    Operator Order: [3, 4, 10, 7, 9, 7, 3, 2, 8, 9, 10, 5, 10, 8]
#
# Group: 28    Unique Ansatze: 1
# Result ID: 8.3    Operator Order: [11, 3, 4, 1, 7, 1, 2, 11, 12, 7, 5, 11, 2, 8]
#
# Group: 29    Unique Ansatze: 1
# Result ID: 8.5    Operator Order: [4, 3, 10, 12, 9, 12, 3, 2, 7, 8, 2, 5, 7, 5]
#
# Group: 30    Unique Ansatze: 1
# Result ID: 8.9    Operator Order: [10, 6, 11, 6, 1, 5, 10, 11, 2, 9, 10, 5, 9, 10]

# %%
# ansatze with same operator set and same frequency of operators

class hashabledict(dict):
    def __hash__(self):
        return hash(tuple(self.items()))

linear_ansatze = [Ansatz(result_id=f'{i}.{j}', geometry='H4_linear')
                  for i in range(1, 9)
                  for j in range(1, 11)]

grouped_ansatze = {}
for ansatz in linear_ansatze:
    operator_freq = hashabledict({operator: ansatz.operators.count(operator) for operator in ansatz.operators})
    if operator_freq in grouped_ansatze:
        grouped_ansatze[operator_freq].append(ansatz)
    else:
        grouped_ansatze[operator_freq] = [ansatz]

grouped_ansatze = list(grouped_ansatze.values())
grouped_ansatze.sort(reverse=True, key=lambda group: len(group))


print(f'Total ansatze number: {len(linear_ansatze)}')
print(f'Unique ansatze number: {len(grouped_ansatze)}')
print(f'Largest group size: {len(grouped_ansatze[0])}', '\n')

for idx, group in enumerate(grouped_ansatze):
    unique_ansatze = len(set([tuple(ansatz.operator_order) for ansatz in group]))
    print(f'Group: {idx+1}    Unique Ansatze: {unique_ansatze}')
    for ansatz in group:
        print(f'Result ID: {ansatz.result_id}    Operator Order: {ansatz.operator_order}')
    print()
# Out:
# Total ansatze number: 80
# Unique ansatze number: 66
# Largest group size: 3
#
# Group: 1    Unique Ansatze: 2
# Result ID: 3.4    Operator Order: [9, 6, 10, 6, 1, 11, 2, 5, 7, 10, 2, 5, 12, 11]
# Result ID: 3.5    Operator Order: [9, 6, 10, 6, 1, 11, 2, 5, 10, 7, 2, 5, 12, 11]
# Result ID: 3.9    Operator Order: [9, 6, 10, 6, 1, 11, 2, 5, 7, 10, 2, 5, 12, 11]
#
# Group: 2    Unique Ansatze: 1
# Result ID: 4.1    Operator Order: [9, 2, 12, 5, 10, 3, 9, 3, 12, 11, 12, 5, 9, 12]
# Result ID: 4.2    Operator Order: [9, 2, 12, 5, 10, 3, 9, 3, 12, 11, 12, 5, 9, 12]
# Result ID: 4.3    Operator Order: [9, 2, 12, 5, 10, 3, 9, 3, 12, 11, 12, 5, 9, 12]
#
# Group: 3    Unique Ansatze: 3
# Result ID: 8.6    Operator Order: [9, 1, 6, 10, 1, 6, 9, 5, 2, 12, 8, 9, 10, 7]
# Result ID: 8.8    Operator Order: [9, 1, 6, 10, 1, 6, 9, 5, 2, 12, 8, 7, 9, 10]
# Result ID: 8.10    Operator Order: [9, 1, 6, 10, 1, 6, 9, 5, 2, 12, 9, 8, 7, 10]
#
# Group: 4    Unique Ansatze: 1
# Result ID: 1.4    Operator Order: [9, 6, 10, 1, 6, 10, 9, 5, 2, 7, 11, 9, 8, 12]
# Result ID: 2.6    Operator Order: [9, 6, 10, 1, 6, 10, 9, 5, 2, 7, 11, 9, 8, 12]
#
# Group: 5    Unique Ansatze: 1
# Result ID: 3.1    Operator Order: [8, 6, 7, 10, 1, 11, 10, 2, 8, 9, 5, 11, 12, 10]
# Result ID: 3.3    Operator Order: [8, 6, 7, 10, 1, 11, 10, 2, 8, 9, 5, 11, 12, 10]
#
# Group: 6    Unique Ansatze: 2
# Result ID: 4.4    Operator Order: [4, 3, 10, 12, 9, 12, 3, 7, 2, 5, 7, 11, 12, 5]
# Result ID: 6.7    Operator Order: [4, 3, 10, 12, 9, 12, 3, 7, 2, 5, 12, 11, 7, 5]
#
# Group: 7    Unique Ansatze: 1
# Result ID: 4.5    Operator Order: [11, 1, 9, 1, 6, 12, 8, 5, 12, 2, 5, 10, 7, 10]
# Result ID: 5.6    Operator Order: [11, 1, 9, 1, 6, 12, 8, 5, 12, 2, 5, 10, 7, 10]
#
# Group: 8    Unique Ansatze: 2
# Result ID: 5.7    Operator Order: [9, 1, 10, 6, 1, 5, 11, 9, 2, 12, 11, 12, 5, 9]
# Result ID: 5.10    Operator Order: [9, 1, 10, 6, 1, 5, 9, 11, 2, 12, 11, 12, 5, 9]
#
# Group: 9    Unique Ansatze: 2
# Result ID: 6.9    Operator Order: [9, 6, 9, 7, 9, 8, 1, 5, 2, 11, 12, 11, 12, 5]
# Result ID: 6.10    Operator Order: [9, 6, 9, 7, 8, 9, 1, 5, 2, 11, 12, 11, 12, 5]
#
# Group: 10    Unique Ansatze: 1
# Result ID: 7.5    Operator Order: [9, 6, 8, 1, 6, 9, 8, 2, 5, 12, 2, 8, 2, 11]
# Result ID: 7.6    Operator Order: [9, 6, 8, 1, 6, 9, 8, 2, 5, 12, 2, 8, 2, 11]
#
# Group: 11    Unique Ansatze: 1
# Result ID: 8.1    Operator Order: [4, 8, 9, 7, 3, 12, 9, 11, 5, 10, 11, 12, 2, 9]
# Result ID: 8.2    Operator Order: [4, 8, 9, 7, 3, 12, 9, 11, 5, 10, 11, 12, 2, 9]
#
# Group: 12    Unique Ansatze: 1
# Result ID: 1.1    Operator Order: [8, 7, 6, 12, 9, 1, 7, 2, 5, 11, 10, 2, 5, 11]
#
# Group: 13    Unique Ansatze: 1
# Result ID: 1.2    Operator Order: [11, 10, 12, 6, 10, 1, 2, 5, 12, 2, 10, 11, 5, 11]
#
# Group: 14    Unique Ansatze: 1
# Result ID: 1.3    Operator Order: [10, 1, 7, 12, 8, 6, 5, 2, 7, 11, 9, 5, 10, 11]
#
# Group: 15    Unique Ansatze: 1
# Result ID: 1.5    Operator Order: [9, 12, 1, 7, 8, 6, 12, 11, 2, 5, 12, 9, 11, 2]
#
# Group: 16    Unique Ansatze: 1
# Result ID: 1.6    Operator Order: [10, 6, 9, 6, 1, 7, 9, 8, 12, 2, 5, 10, 9, 11]
#
# Group: 17    Unique Ansatze: 1
# Result ID: 1.7    Operator Order: [9, 7, 6, 8, 9, 1, 8, 2, 5, 7, 10, 2, 5, 11]
#
# Group: 18    Unique Ansatze: 1
# Result ID: 1.8    Operator Order: [11, 6, 11, 7, 9, 1, 11, 2, 5, 7, 11, 5, 12, 8]
#
# Group: 19    Unique Ansatze: 1
# Result ID: 1.9    Operator Order: [8, 1, 11, 1, 6, 9, 2, 11, 8, 9, 5, 12, 11, 5]
#
# Group: 20    Unique Ansatze: 1
# Result ID: 1.10    Operator Order: [8, 1, 11, 1, 6, 2, 12, 5, 7, 11, 12, 10, 5, 12]
#
# Group: 21    Unique Ansatze: 1
# Result ID: 2.1    Operator Order: [9, 8, 6, 9, 12, 1, 8, 2, 12, 2, 11, 12, 5, 9]
#
# Group: 22    Unique Ansatze: 1
# Result ID: 2.2    Operator Order: [9, 10, 1, 6, 2, 11, 8, 2, 5, 7, 12, 2, 8, 9]
#
# Group: 23    Unique Ansatze: 1
# Result ID: 2.3    Operator Order: [9, 10, 1, 6, 5, 7, 5, 10, 11, 12, 2, 9, 11, 5]
#
# Group: 24    Unique Ansatze: 1
# Result ID: 2.4    Operator Order: [10, 6, 9, 6, 1, 5, 12, 8, 5, 9, 2, 10, 9, 7]
#
# Group: 25    Unique Ansatze: 1
# Result ID: 2.5    Operator Order: [10, 6, 7, 11, 1, 5, 9, 12, 2, 9, 8, 2, 7, 8]
#
# Group: 26    Unique Ansatze: 1
# Result ID: 2.7    Operator Order: [10, 9, 5, 6, 10, 1, 2, 5, 10, 11, 8, 5, 7, 2]
#
# Group: 27    Unique Ansatze: 1
# Result ID: 2.8    Operator Order: [11, 1, 9, 1, 6, 5, 8, 12, 11, 2, 5, 10, 5, 12]
#
# Group: 28    Unique Ansatze: 1
# Result ID: 2.9    Operator Order: [11, 6, 1, 9, 6, 1, 9, 5, 11, 2, 7, 11, 8, 9]
#
# Group: 29    Unique Ansatze: 1
# Result ID: 2.10    Operator Order: [10, 9, 5, 6, 10, 1, 2, 5, 10, 11, 12, 5, 8, 2]
#
# Group: 30    Unique Ansatze: 1
# Result ID: 3.2    Operator Order: [8, 6, 7, 11, 1, 12, 2, 7, 9, 11, 5, 11, 9, 11]
#
# Group: 31    Unique Ansatze: 1
# Result ID: 3.6    Operator Order: [8, 1, 12, 10, 8, 6, 8, 2, 5, 9, 5, 10, 11, 10]
#
# Group: 32    Unique Ansatze: 1
# Result ID: 3.7    Operator Order: [11, 9, 1, 8, 6, 2, 12, 2, 7, 5, 11, 9, 2, 8]
#
# Group: 33    Unique Ansatze: 1
# Result ID: 3.8    Operator Order: [8, 6, 9, 7, 8, 1, 9, 5, 2, 11, 9, 11, 12, 5]
#
# Group: 34    Unique Ansatze: 1
# Result ID: 3.10    Operator Order: [10, 7, 6, 11, 1, 5, 7, 12, 8, 2, 11, 7, 9, 2]
#
# Group: 35    Unique Ansatze: 1
# Result ID: 4.6    Operator Order: [8, 6, 11, 6, 1, 9, 8, 5, 11, 5, 7, 2, 9, 11]
#
# Group: 36    Unique Ansatze: 1
# Result ID: 4.7    Operator Order: [10, 6, 9, 6, 1, 11, 2, 5, 7, 10, 7, 5, 12, 11]
#
# Group: 37    Unique Ansatze: 1
# Result ID: 4.8    Operator Order: [9, 11, 1, 8, 6, 7, 12, 2, 5, 11, 10, 5, 11, 9]
#
# Group: 38    Unique Ansatze: 1
# Result ID: 4.9    Operator Order: [2, 6, 7, 9, 12, 1, 7, 2, 5, 8, 7, 2, 8, 9]
#
# Group: 39    Unique Ansatze: 1
# Result ID: 4.10    Operator Order: [8, 1, 7, 6, 12, 8, 6, 5, 7, 10, 2, 10, 2, 8]
#
# Group: 40    Unique Ansatze: 1
# Result ID: 5.1    Operator Order: [10, 7, 12, 6, 8, 1, 10, 11, 5, 2, 12, 5, 7, 9]
#
# Group: 41    Unique Ansatze: 1
# Result ID: 5.2    Operator Order: [10, 11, 1, 12, 11, 6, 2, 8, 7, 2, 11, 9, 5, 11]
#
# Group: 42    Unique Ansatze: 1
# Result ID: 5.3    Operator Order: [8, 1, 8, 10, 8, 1, 6, 3, 9, 3, 12, 11, 5, 11]
#
# Group: 43    Unique Ansatze: 1
# Result ID: 5.4    Operator Order: [10, 12, 1, 11, 6, 7, 2, 11, 12, 5, 10, 11, 7, 9]
#
# Group: 44    Unique Ansatze: 1
# Result ID: 5.5    Operator Order: [10, 6, 9, 6, 1, 8, 9, 8, 12, 2, 5, 12, 9, 12]
#
# Group: 45    Unique Ansatze: 1
# Result ID: 5.8    Operator Order: [4, 3, 10, 7, 9, 7, 3, 7, 2, 5, 11, 12, 11, 5]
#
# Group: 46    Unique Ansatze: 1
# Result ID: 5.9    Operator Order: [8, 6, 11, 1, 6, 8, 11, 12, 9, 2, 8, 5, 7, 8]
#
# Group: 47    Unique Ansatze: 1
# Result ID: 6.1    Operator Order: [5, 2, 9, 8, 3, 9, 3, 2, 11, 9, 5, 11, 5, 7]
#
# Group: 48    Unique Ansatze: 1
# Result ID: 6.2    Operator Order: [5, 2, 9, 8, 3, 9, 3, 2, 11, 9, 7, 11, 5, 12]
#
# Group: 49    Unique Ansatze: 1
# Result ID: 6.3    Operator Order: [5, 8, 10, 2, 7, 8, 3, 10, 9, 3, 2, 7, 9, 7]
#
# Group: 50    Unique Ansatze: 1
# Result ID: 6.4    Operator Order: [10, 1, 8, 1, 6, 9, 12, 5, 2, 9, 10, 7, 12, 11]
#
# Group: 51    Unique Ansatze: 1
# Result ID: 6.5    Operator Order: [8, 1, 11, 6, 1, 10, 5, 12, 11, 5, 12, 2, 9, 10]
#
# Group: 52    Unique Ansatze: 1
# Result ID: 6.6    Operator Order: [8, 6, 7, 9, 1, 10, 8, 2, 7, 5, 11, 10, 8, 10]
#
# Group: 53    Unique Ansatze: 1
# Result ID: 6.8    Operator Order: [4, 3, 10, 12, 9, 12, 3, 7, 2, 5, 10, 12, 11, 5]
#
# Group: 54    Unique Ansatze: 1
# Result ID: 7.1    Operator Order: [2, 5, 9, 7, 5, 2, 6, 12, 6, 11, 10, 9, 5, 8]
#
# Group: 55    Unique Ansatze: 1
# Result ID: 7.2    Operator Order: [10, 11, 12, 11, 5, 2, 3, 9, 3, 8, 7, 9, 2, 8]
#
# Group: 56    Unique Ansatze: 1
# Result ID: 7.3    Operator Order: [9, 10, 1, 7, 6, 5, 2, 12, 8, 12, 8, 2, 9, 5]
#
# Group: 57    Unique Ansatze: 1
# Result ID: 7.4    Operator Order: [10, 7, 1, 6, 8, 1, 10, 11, 5, 2, 12, 5, 7, 9]
#
# Group: 58    Unique Ansatze: 1
# Result ID: 7.7    Operator Order: [4, 3, 10, 12, 9, 12, 3, 11, 2, 5, 11, 12, 11, 5]
#
# Group: 59    Unique Ansatze: 1
# Result ID: 7.8    Operator Order: [11, 2, 9, 5, 8, 3, 10, 1, 10, 2, 12, 5, 9, 5]
#
# Group: 60    Unique Ansatze: 1
# Result ID: 7.9    Operator Order: [11, 2, 7, 5, 4, 3, 12, 11, 10, 8, 9, 12, 4, 6]
#
# Group: 61    Unique Ansatze: 1
# Result ID: 7.10    Operator Order: [3, 4, 10, 7, 9, 7, 3, 2, 8, 9, 10, 5, 10, 8]
#
# Group: 62    Unique Ansatze: 1
# Result ID: 8.3    Operator Order: [11, 3, 4, 1, 7, 1, 2, 11, 12, 7, 5, 11, 2, 8]
#
# Group: 63    Unique Ansatze: 1
# Result ID: 8.4    Operator Order: [9, 1, 6, 10, 1, 6, 9, 5, 2, 12, 8, 9, 7, 11]
#
# Group: 64    Unique Ansatze: 1
# Result ID: 8.5    Operator Order: [4, 3, 10, 12, 9, 12, 3, 2, 7, 8, 2, 5, 7, 5]
#
# Group: 65    Unique Ansatze: 1
# Result ID: 8.7    Operator Order: [10, 11, 6, 11, 1, 8, 9, 5, 7, 11, 2, 8, 10, 9]
#
# Group: 66    Unique Ansatze: 1
# Result ID: 8.9    Operator Order: [10, 6, 11, 6, 1, 5, 10, 11, 2, 9, 10, 5, 9, 10]

# %%
ansatz1 = Ansatz(result_id='5.7')
ansatz2 = Ansatz(result_id='5.10')
s = [round(i, 2) for i in list(np.array(ansatz1.phases_radians) / np.array(ansatz2.phases_radians))]

# %%
ansatz1 = Ansatz(result_id='5.8')
ansatz2 = Ansatz(result_id='7.7')

s = [round(i, 2) for i in list(np.array(ansatz1.phases_radians) / np.array(ansatz2.phases_radians))]

# %%
for group in grouped_ansatze:
    if len(set([tuple(ansatz.operator_order) for ansatz in group])) > 1:
        for item in [f'Result ID: {ansatz.result_id}  Operator Order: {ansatz.operator_order}' for ansatz in group]:
            print(item)
        print()
# Out:
# Result ID: 3.4  Operator Order: [9, 6, 10, 6, 1, 11, 2, 5, 7, 10, 2, 5, 12, 11]
# Result ID: 3.5  Operator Order: [9, 6, 10, 6, 1, 11, 2, 5, 10, 7, 2, 5, 12, 11]
# Result ID: 3.9  Operator Order: [9, 6, 10, 6, 1, 11, 2, 5, 7, 10, 2, 5, 12, 11]
#
# Result ID: 8.6  Operator Order: [9, 1, 6, 10, 1, 6, 9, 5, 2, 12, 8, 9, 10, 7]
# Result ID: 8.8  Operator Order: [9, 1, 6, 10, 1, 6, 9, 5, 2, 12, 8, 7, 9, 10]
# Result ID: 8.10  Operator Order: [9, 1, 6, 10, 1, 6, 9, 5, 2, 12, 9, 8, 7, 10]
#
# Result ID: 4.4  Operator Order: [4, 3, 10, 12, 9, 12, 3, 7, 2, 5, 7, 11, 12, 5]
# Result ID: 6.7  Operator Order: [4, 3, 10, 12, 9, 12, 3, 7, 2, 5, 12, 11, 7, 5]
#
# Result ID: 5.7  Operator Order: [9, 1, 10, 6, 1, 5, 11, 9, 2, 12, 11, 12, 5, 9]
# Result ID: 5.10  Operator Order: [9, 1, 10, 6, 1, 5, 9, 11, 2, 12, 11, 12, 5, 9]
#
# Result ID: 6.9  Operator Order: [9, 6, 9, 7, 9, 8, 1, 5, 2, 11, 12, 11, 12, 5]
# Result ID: 6.10  Operator Order: [9, 6, 9, 7, 8, 9, 1, 5, 2, 11, 12, 11, 12, 5]

# %%
gadget1 = Gadget(num_qubits=8, phase=1/2, pauli_str='YZZZX')
gadget2 = Gadget(num_qubits=8, phase=-1/2, pauli_str='XZZZY')
gadget3 = Gadget(num_qubits=8, phase=1/2, pauli_str='IYZZZX')
gadget4 = Gadget(num_qubits=8, phase=-1/2, pauli_str='IXZZZY')

gadget = gadget2 + gadget4 + gadget1 + gadget3
print(gadget2.hub_node.ref, gadget4.hub_node.ref, gadget3.hub_node.ref, gadget1.hub_node.ref)
gadget.draw()
# Out:
# WARNING Cannot add <class 'zxfermion.types.Gadget'> and <class 'zxfermion.types.Gadget'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       3 gadget3 = Gadget(num_qubits=8, phase=1/2, pauli_str='IYZZZX')
#       4 gadget4 = Gadget(num_qubits=8, phase=-1/2, pauli_str='IXZZZY')
# ----> 6 gadget = gadget2 + gadget4 + gadget1 + gadget3
#       7 print(gadget2.hub_node.ref, gadget4.hub_node.ref, gadget3.hub_node.ref, gadget1.hub_node.ref)
#       8 gadget.draw()
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'Gadget'

# %%
from enum import Enum

class LegType(str, Enum):
    X = 'X'
    Y = 'Y'
    Z = 'Z'

s = LegType('Y')
